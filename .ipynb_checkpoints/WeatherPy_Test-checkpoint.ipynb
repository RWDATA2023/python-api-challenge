# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 614

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | point pedro
# Processing Record 2 of Set 1 | isafjordur
# Processing Record 3 of Set 1 | port lincoln
# Processing Record 4 of Set 1 | dudinka
# Processing Record 5 of Set 1 | port-aux-francais
# Processing Record 6 of Set 1 | al jumum
# Processing Record 7 of Set 1 | kudahuvadhoo
# Processing Record 8 of Set 1 | lata
# Processing Record 9 of Set 1 | gamba
# Processing Record 10 of Set 1 | grytviken
# Processing Record 11 of Set 1 | merizo village
# Processing Record 12 of Set 1 | fairfield glade
# Processing Record 13 of Set 1 | brigantine
# Processing Record 14 of Set 1 | hawaiian paradise park
# Processing Record 15 of Set 1 | zambezi
# Processing Record 16 of Set 1 | college
# Processing Record 17 of Set 1 | nikolayevsk-on-amure
# Processing Record 18 of Set 1 | tolanaro
# Processing Record 19 of Set 1 | magdagachi
# Processing Record 20 of Set 1 | coquimbo
# Processing Record 21 of Set 1 | adamstown
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | vega de alatorre
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | kailua-kona
# Processing Record 26 of Set 1 | talnakh
# Processing Record 27 of Set 1 | edinburgh of the seven seas
# Processing Record 28 of Set 1 | olonkinbyen
# Processing Record 29 of Set 1 | jacutinga
# Processing Record 30 of Set 1 | bargara
# City not found. Skipping...
# Processing Record 31 of Set 1 | puerto natales
# Processing Record 32 of Set 1 | nar'yan-mar
# Processing Record 33 of Set 1 | nkove
# Processing Record 34 of Set 1 | badger
# Processing Record 35 of Set 1 | papatowai
# Processing Record 36 of Set 1 | wailua homesteads
# Processing Record 37 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 38 of Set 1 | fort bragg
# Processing Record 39 of Set 1 | stanley
# Processing Record 40 of Set 1 | riohacha
# Processing Record 41 of Set 1 | port alfred
# Processing Record 42 of Set 1 | howrah
# Processing Record 43 of Set 1 | iskateley
# Processing Record 44 of Set 1 | georgetown
# Processing Record 45 of Set 1 | bethel
# Processing Record 46 of Set 1 | ribeira grande
# Processing Record 47 of Set 1 | vershino-darasunskiy
# Processing Record 48 of Set 1 | puerto aysen
# Processing Record 49 of Set 1 | luanda
# Processing Record 50 of Set 1 | zhangjiajie
# Processing Record 0 of Set 2 | utrik
# Processing Record 1 of Set 2 | invercargill
# Processing Record 2 of Set 2 | klyuchi
# Processing Record 3 of Set 2 | vanimo
# Processing Record 4 of Set 2 | st. john's
# Processing Record 5 of Set 2 | alamosa
# Processing Record 6 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 7 of Set 2 | tsiombe
# Processing Record 8 of Set 2 | quellon
# Processing Record 9 of Set 2 | west island
# Processing Record 10 of Set 2 | afaahiti
# Processing Record 11 of Set 2 | savave village
# City not found. Skipping...
# Processing Record 12 of Set 2 | prainha
# Processing Record 13 of Set 2 | puerto ayora
# Processing Record 14 of Set 2 | remire-montjoly
# Processing Record 15 of Set 2 | port elizabeth
# Processing Record 16 of Set 2 | hell-ville
# Processing Record 17 of Set 2 | huarmey
# Processing Record 18 of Set 2 | waitangi
# Processing Record 19 of Set 2 | lebu
# Processing Record 20 of Set 2 | kenora
# Processing Record 21 of Set 2 | betio village
# Processing Record 22 of Set 2 | port mathurin
# Processing Record 23 of Set 2 | anna regina
# Processing Record 24 of Set 2 | villa gesell
# Processing Record 25 of Set 2 | kolondieba
# Processing Record 26 of Set 2 | nizao
# Processing Record 0 of Set 4 | ibiza
# Processing Record 1 of Set 4 | tabou
# Processing Record 2 of Set 4 | san salvador de jujuy
# Processing Record 3 of Set 4 | guerrero negro
# Processing Record 4 of Set 4 | saldanha
# Processing Record 5 of Set 4 | tiksi
# Processing Record 6 of Set 4 | siracusa
# Processing Record 7 of Set 4 | kristiansund
# Processing Record 8 of Set 4 | hengshui
# Processing Record 9 of Set 4 | champerico
# Processing Record 10 of Set 4 | peterhead
# Processing Record 11 of Set 4 | sihanoukville
# Processing Record 12 of Set 4 | zaozersk
# Processing Record 13 of Set 4 | maxixe
# Processing Record 14 of Set 4 | aguililla
# Processing Record 15 of Set 4 | hinton
# Processing Record 16 of Set 4 | cockburn town
# Processing Record 17 of Set 4 | anadyr
# Processing Record 18 of Set 4 | ancud
# Processing Record 19 of Set 4 | ad dawadimi
# Processing Record 20 of Set 4 | gao
# Processing Record 21 of Set 4 | lebanon
# Processing Record 22 of Set 4 | hermanus
# Processing Record 23 of Set 4 | uturoa
# Processing Record 24 of Set 4 | kingston
# Processing Record 25 of Set 4 | namibe
# Processing Record 26 of Set 4 | dadhar
# Processing Record 27 of Set 4 | el colorado
# Processing Record 28 of Set 4 | sitka
# Processing Record 29 of Set 4 | mar del plata
# Processing Record 30 of Set 4 | taoudenni
# Processing Record 31 of Set 4 | gadzhiyevo
# Processing Record 32 of Set 4 | debila
# Processing Record 33 of Set 4 | cova figueira
# Processing Record 34 of Set 4 | sandnessjoen
# Processing Record 35 of Set 4 | valparaiso
# Processing Record 36 of Set 4 | hovd
# Processing Record 37 of Set 4 | raduzhny
# Processing Record 38 of Set 4 | koubia
# Processing Record 39 of Set 4 | acapulco de juarez
# Processing Record 40 of Set 4 | junin de los andes
# Processing Record 41 of Set 4 | lagoa
# Processing Record 42 of Set 4 | onega
# Processing Record 43 of Set 4 | karratha
# Processing Record 44 of Set 4 | 'ohonua
# City not found. Skipping...
# Processing Record 45 of Set 4 | lihue
# Processing Record 46 of Set 4 | ambatofinandrahana
# Processing Record 47 of Set 4 | nadym
# Processing Record 48 of Set 4 | cannonvale
# Processing Record 49 of Set 4 | luderitz
# Processing Record 0 of Set 5 | komsomol'skiy
# Processing Record 1 of Set 5 | ampahana
# City not found. Skipping...
# Processing Record 2 of Set 5 | muscat
# Processing Record 3 of Set 5 | acarau
# Processing Record 4 of Set 5 | shimoda
# Processing Record 5 of Set 5 | nadi
# Processing Record 6 of Set 5 | linhares
# Processing Record 7 of Set 5 | nizhnedevitsk
# Processing Record 8 of Set 5 | cabo san lucas
# Processing Record 9 of Set 5 | sinabang
# Processing Record 10 of Set 5 | san luis acatlan
# Processing Record 11 of Set 5 | sisimiut
# Processing Record 12 of Set 5 | richards bay
# Processing Record 13 of Set 5 | carnarvon
# Processing Record 14 of Set 5 | kavaratti
# Processing Record 15 of Set 5 | bilibino
# Processing Record 16 of Set 5 | astoria
# Processing Record 17 of Set 5 | fomboni
# Processing Record 18 of Set 5 | robertsport
# Processing Record 19 of Set 5 | al burayqah
# Processing Record 20 of Set 5 | saint-francois
# Processing Record 21 of Set 5 | klaksvik
# Processing Record 22 of Set 5 | vadso
# Processing Record 23 of Set 5 | malanje
# Processing Record 24 of Set 5 | bayan nur
# City not found. Skipping...
# Processing Record 25 of Set 5 | gelemso
# Processing Record 26 of Set 5 | bikenibeu village
# Processing Record 27 of Set 5 | gourcy
# Processing Record 28 of Set 5 | yuzhno-kurilsk
# Processing Record 29 of Set 5 | ho
# City not found. Skipping...
# Processing Record 30 of Set 5 | havre
# Processing Record 31 of Set 5 | delta
# Processing Record 32 of Set 5 | kapiri mposhi
# Processing Record 33 of Set 5 | thompson
# Processing Record 34 of Set 5 | cidreira
# Processing Record 35 of Set 5 | posto fiscal rolim de moura
# Processing Record 36 of Set 5 | george town
# Processing Record 37 of Set 5 | tabas
# Processing Record 38 of Set 5 | shubarshi
# Processing Record 39 of Set 5 | karyes
# Processing Record 40 of Set 5 | pyt-yakh
# Processing Record 41 of Set 5 | priob'ye
# Processing Record 42 of Set 5 | malindi
# Processing Record 43 of Set 5 | abepura
# Processing Record 44 of Set 5 | vorkuta
# Processing Record 45 of Set 5 | polyarnyy
# Processing Record 46 of Set 5 | chita
# Processing Record 47 of Set 5 | cuamba
# Processing Record 48 of Set 5 | greenville
# Processing Record 49 of Set 5 | jining
# Processing Record 0 of Set 6 | enewetak
# Processing Record 1 of Set 6 | ziro
# Processing Record 2 of Set 6 | fort mcmurray
# Processing Record 3 of Set 6 | tranovaho
# City not found. Skipping...
# Processing Record 4 of Set 6 | noumea
# Processing Record 5 of Set 6 | prince rupert
# Processing Record 6 of Set 6 | luwuk
# Processing Record 7 of Set 6 | damghan
# Processing Record 8 of Set 6 | magadan
# Processing Record 9 of Set 6 | saint-pierre
# Processing Record 10 of Set 6 | gebeit
# Processing Record 11 of Set 6 | dingcheng
# Processing Record 12 of Set 6 | crane
# Processing Record 13 of Set 6 | island harbour
# Processing Record 14 of Set 6 | sultanah
# Processing Record 15 of Set 6 | naze
# Processing Record 16 of Set 6 | ingeniero jacobacci
# Processing Record 17 of Set 6 | kushiro
# Processing Record 18 of Set 6 | mayya
# Processing Record 19 of Set 6 | al khawr
# Processing Record 20 of Set 6 | segezha
# Processing Record 21 of Set 6 | shantobe
# Processing Record 22 of Set 6 | khorixas
# Processing Record 23 of Set 6 | vila velha
# Processing Record 24 of Set 6 | new plymouth
# Processing Record 25 of Set 6 | san julian
# Processing Record 26 of Set 6 | bodo
# Processing Record 27 of Set 6 | san patricio
# Processing Record 28 of Set 6 | hithadhoo
# Processing Record 29 of Set 6 | el nido
# Processing Record 30 of Set 6 | villamontes
# Processing Record 31 of Set 6 | luau
# Processing Record 32 of Set 6 | constantia
# Processing Record 33 of Set 6 | kuhmo
# Processing Record 34 of Set 6 | san luis
# Processing Record 35 of Set 6 | gamay
# Processing Record 36 of Set 6 | pisco
# Processing Record 37 of Set 6 | muynoq
# Processing Record 38 of Set 6 | ola
# Processing Record 39 of Set 6 | tual
# Processing Record 40 of Set 6 | nova sintra
# Processing Record 41 of Set 6 | freetown
# Processing Record 42 of Set 6 | siwa oasis
# Processing Record 43 of Set 6 | cadale
# Processing Record 44 of Set 6 | kapuskasing
# Processing Record 45 of Set 6 | dzhalil'
# Processing Record 46 of Set 6 | ust-nera
# Processing Record 47 of Set 6 | tura
# Processing Record 48 of Set 6 | belyy yar
# Processing Record 49 of Set 6 | petropavlovsk-kamchatsky
# Processing Record
# Processing Record 46 of Set 9 | alofi
# Processing Record 47 of Set 9 | am timan
# Processing Record 48 of Set 9 | labrador city
# Processing Record 49 of Set 9 | midland
# Processing Record 0 of Set 10 | murudeshwara
# Processing Record 1 of Set 10 | iesolo
# Processing Record 2 of Set 10 | maun
# Processing Record 3 of Set 10 | khandyga
# Processing Record 4 of Set 10 | papao
# Processing Record 5 of Set 10 | al ghayzah
# Processing Record 6 of Set 10 | mbanza-ngungu
# Processing Record 7 of Set 10 | san pedro
# Processing Record 8 of Set 10 | rio turbio
# City not found. Skipping...
# Processing Record 9 of Set 10 | arraial do cabo
# Processing Record 10 of Set 10 | lichinga
# Processing Record 11 of Set 10 | santana
# Processing Record 12 of Set 10 | graaff-reinet
# Processing Record 13 of Set 10 | mccook
# Processing Record 14 of Set 10 | novogrudok
# Processing Record 15 of Set 10 | sambava
# Processing Record 16 of Set 10 | nizhneangarsk
# Processing Record 17 of Set 10 | patterson
# Processing Record 18 of Set 10 | port isabel
# Processing Record 19 of Set 10 | yatou
# Processing Record 20 of Set 10 | livingston
# Processing Record 21 of Set 10 | porto velho
# Processing Record 22 of Set 10 | dongola
# Processing Record 23 of Set 10 | sant'antioco
# Processing Record 24 of Set 10 | kidal
# Processing Record 25 of Set 10 | qulsary
# Processing Record 26 of Set 10 | ilhabela
# Processing Record 27 of Set 10 | songea
# Processing Record 28 of Set 10 | antalaha
# Processing Record 29 of Set 10 | kununurra
# Processing Record 30 of Set 10 | dompu
# Processing Record 31 of Set 10 | colonia
# Processing Record 32 of Set 10 | lingig
# Processing Record 33 of Set 10 | new norfolk
# Processing Record 34 of Set 10 | pajeczno
# Processing Record 35 of Set 10 | kapa'a
# Processing Record 36 of Set 10 | walvis bay
# Processing Record 37 of Set 10 | port saint john's
# Processing Record 38 of Set 10 | faulquemont
# Processing Record 39 of Set 10 | dolores
# Processing Record 40 of Set 10 | gerash
# Processing Record 41 of Set 10 | tanda
# Processing Record 42 of Set 10 | salekhard
# Processing Record 43 of Set 10 | nemuro
# Processing Record 44 of Set 10 | arkhangel'sk
# Processing Record 45 of Set 10 | tinajo
# Processing Record 46 of Set 10 | yeppoon
# Processing Record 47 of Set 10 | kyshtovka
# Processing Record 48 of Set 10 | murghob
# Processing Record 49 of Set 10 | higuera de zaragoza
# Processing Record 0 of Set 11 | yinchuan
# Processing Record 1 of Set 11 | machico
# Processing Record 2 of Set 11 | palmer
# Processing Record 3 of Set 11 | swift current
# Processing Record 4 of Set 11 | am djarass
# City not found. Skipping...
# Processing Record 5 of Set 11 | minas de matahambre
# City not found. Skipping...
# Processing Record 6 of Set 11 | vizinga
# Processing Record 7 of Set 11 | lerwick
# Processing Record 8 of Set 11 | fort st. john
# Processing Record 9 of Set 11 | znamenskoye
# Processing Record 10 of Set 11 | ponta delgada
# Processing Record 11 of Set 11 | lycksele
# Processing Record 12 of Set 11 | pemangkat
# Processing Record 13 of Set 11 | yarmouth
# Processing Record 14 of Set 11 | concordia
# Processing Record 15 of Set 11 | dakhla
# Processing Record 16 of Set 11 | pingzhuang
# Processing Record 17 of Set 11 | yilan
# Processing Record 18 of Set 11 | tonghae
# Processing Record 19 of Set 11 | pont rouge
# Processing Record 20 of Set 11 | dedougou
# Processing Record 21 of Set 11 | tanjung pandan
# Processing Record 22 of Set 11 | hayma'
# City not found. Skipping...
# Processing Record 23 of Set 11 | kota tinggi
# Processing Record 24 of Set 11 | fale old settlement
# Processing Record 25 of Set 11 | saint-joseph
# Processing Record 26 of Set 11 | taulaga
# Processing Record 27 of Set 11 | simpang
# Processing Record 28 of Set 11 | buta
# Processing Record 29 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 30 of Set 11 | yol
# Processing Record 31 of Set 11 | lorengau
# Processing Record 32 of Set 11 | flagstaff
# Processing Record 33 of Set 11 | mogocha
# Processing Record 34 of Set 11 | paciran
# Processing Record 35 of Set 11 | puerto baquerizo moreno
# Processing Record 36 of Set 11 | pont-sainte-maxence
# Processing Record 37 of Set 11 | mutuali
# Processing Record 38 of Set 11 | filey
# Processing Record 39 of Set 11 | president roxas
# Processing Record 40 of Set 11 | nangis
# Processing Record 41 of Set 11 | geraldton
# Processing Record 42 of Set 11 | hamilton
# Processing Record 43 of Set 11 | wuzhou
# Processing Record 44 of Set 11 | ritchie
# Processing Record 45 of Set 11 | pesqueira
# Processing Record 46 of Set 11 | viqueque
# Processing Record 47 of Set 11 | natal
# Processing Record 48 of Set 11 | estacion coahuila
# Processing Record 49 of Set 11 | harstad
# Processing Record 0 of Set 12 | riyadh
# Processing Record 1 of Set 12 | olgii
# City not found. Skipping...
# Processing Record 2 of Set 12 | mossel bay
# Processing Record 3 of Set 12 | fereydun kenar
# Processing Record 4 of Set 12 | viedma
# Processing Record 5 of Set 12 | mejit
# Processing Record 6 of Set 12 | kerikeri
# Processing Record 7 of Set 12 | vilyeyka
# Processing Record 8 of Set 12 | san luis de la loma
# Processing Record 9 of Set 12 | rengasdengklok
# Processing Record 10 of Set 12 | ust'-kulom
# Processing Record 11 of Set 12 | kindu
# Processing Record 12 of Set 12 | vallenar
# Processing Record 13 of Set 12 | weiser
# Processing Record 14 of Set 12 | twon-brass
# Processing Record 15 of Set 12 | xining
# Processing Record 16 of Set 12 | benguela
# Processing Record 17 of Set 12 | dhromolaxia
# Processing Record 18 of Set 12 | san rafael del sur
# Processing Record 19 of Set 12 | illizi
# Processing Record 20 of Set 12 | dabakala
# Processing Record 21 of Set 12 | beau vallon
# Processing Record 22 of Set 12 | bonny
# Processing Record 23 of Set 12 | ust'-barguzin
# Processing Record 24 of Set 12 | amungan
# Processing Record 25 of Set 12 | riacho de santana
# Processing Record 26 of Set 12 | pointe-noire
# Processing Record 27 of Set 12 | malvan
# Processing Record 28 of Set 12 | port blair
# Processing Record 29 of Set 12 | rikaze
# Processing Record 30 of Set 12 | vredendal
# Processing Record 31 of Set 12 | labytnangi
# Processing Record 32 of Set 12 | ciudad lazaro cardenas
# Processing Record 33 of Set 12 | artigas
# Processing Record 34 of Set 12 | tandalti
# Processing Record 35 of Set 12 | urangan
# Processing Record 36 of Set 12 | matsue
# Processing Record 37 of Set 12 | san andres
# Processing Record 38 of Set 12 | meulaboh
# Processing Record 39 of Set 12 | san jose de feliciano
# Processing Record 40 of Set 12 | alliance
# Processing Record 41 of Set 12 | xinyuan
# Processing Record 42 of Set 12 | kyzyl
# Processing Record 43 of Set 12 | margate
# Processing Record 44 of Set 12 | tazacorte
# Processing Record 45 of Set 12 | ghanzi
# Processing Record 46 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 47 of Set 12 | les cayes
# Processing Record 48 of Set 12 | mount pearl
# Processing Record 49 of Set 12 | igrim
# Processing Record 0 of Set 13 | susuman
# Processing Record 1 of Set 13 | bogatoye
# Processing Record 2 of Set 13 | port-vila
# Processing Record 3 of Set 13 | stephenville
# Processing Record 4 of Set 13 | trincomalee
# Processing Record 5 of Set 13 | bako
# Processing Record 6 of Set 13 | katsuren-haebaru
# Processing Record 7 of Set 13 | korla
# Processing Record 8 of Set 13 | suwayr
# Processing Record 9 of Set 13 | minot
# Processing Record 10 of Set 13 | tangalle
# Processing Record 11 of Set 13 | fartura
# Processing Record 12 of Set 13 | nema
# Processing Record 13 of Set 13 | krasnovishersk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          586
# Lat           586
# Lng           586
# Max Temp      586
# Humidity      586
# Cloudiness    586
# Wind Speed    586
# Country       586
# Date          586
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        point pedro   9.8167   80.2333     83.48        79          21
# 1         isafjordur  66.0755  -23.1240     41.76        66          86
# 2       port lincoln -34.7333  135.8667     56.91        73         100
# 3            dudinka  69.4058   86.1778     33.62        96         100
# 4  port-aux-francais -49.3500   70.2167     44.24        86          79
#
#    Wind Speed Country        Date
# 0       12.35      LK  1684795323
# 1        6.49      IS  1684795323
# 2       10.71      AU  1684795324
# 3       20.65      RU  1684795324
# 4       23.49      TF  1684795324

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              point pedro   9.8167   80.2333     83.48        79          21
# 1               isafjordur  66.0755  -23.1240     41.76        66          86
# 2             port lincoln -34.7333  135.8667     56.91        73         100
# 3                  dudinka  69.4058   86.1778     33.62        96         100
# 4        port-aux-francais -49.3500   70.2167     44.24        86          79
#
#          Wind Speed Country        Date
# City_ID
# 0             12.35      LK  1684795323
# 1              6.49      IS  1684795323
# 2             10.71      AU  1684795324
# 3             20.65      RU  1684795324
# 4             23.49      TF  1684795324

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (°F)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def create_linear_regression_plot(x_values, y_values, x_label, y_label, hemisphere):
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    
    # Calculate the regression line
    regress_values = x_values * slope + intercept
    
    # Create scatter plot
    plt.scatter(x_values, y_values, edgecolors="black")
    
    # Plot the regression line
    plt.plot(x_values, regress_values, "r-")
    
    # Annotate the linear regression equation and r-value
    equation = f"y = {slope:.2f}x + {intercept:.2f}"
    r_value = f"r = {rvalue:.2f}"
    plt.annotate(equation, (min(x_values), min(y_values)), fontsize=12, color="red")
    plt.annotate(r_value, (min(x_values), min(y_values) + (max(y_values)-min(y_values))/4), fontsize=12, color="red")
    
    # Set the title, x-label, y-label, and grid
    title = f"{hemisphere} Hemisphere: {y_label} vs. {x_label}"
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.grid(True)
    
    # Save the figure
    plt.savefig(f"output_data/{hemisphere}_{x_label}_{y_label}.png")
    
    # Show the plot
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         point pedro   9.8167  80.2333     83.48        79          21
# 1          isafjordur  66.0755 -23.1240     41.76        66          86
# 3             dudinka  69.4058  86.1778     33.62        96         100
# 5            al jumum  21.6169  39.6981     84.15        31           2
# 6        kudahuvadhoo   2.6708  72.8944     82.92        73           3
#
#          Wind Speed Country        Date
# City_ID
# 0             12.35      LK  1684795323
# 1              6.49      IS  1684795323
# 3             20.65      RU  1684795324
# 5              5.30      SA  1684795324
# 6              5.77      MV  1684795324

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2             port lincoln -34.7333  135.8667     56.91        73         100
# 4        port-aux-francais -49.3500   70.2167     44.24        86          79
# 8                    gamba  -2.6500   10.0000     75.33        89          86
# 9                grytviken -54.2811  -36.5092     40.50        97         100
# 14                 zambezi -13.5432   23.1047     60.69        47          22
#
#          Wind Speed Country        Date
# City_ID
# 2             10.71      AU  1684795324
# 4             23.49      TF  1684795324
# 8              3.98      GA  1684795325
# 9              7.36      GS  1684795325
# 14             2.13      ZM  1684795326

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression plot on Northern Hemisphere - Temperature vs. Latitude
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Calculate regression line values
regress_values = x_values * slope + intercept

# Create scatter plot
plt.scatter(x_values, y_values)

# Plot regression line
plt.plot(x_values, regress_values, "r")

# Annotate the equation of the line
line_eq = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
plt.annotate(line_eq, (10, 20), fontsize=15, color="red")

# Set labels and title
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("Northern Hemisphere - Max Temperature vs. Latitude")

# Show plot
plt.show()

# %%
# Linear regression plot on Southern Hemisphere - Temperature vs. Latitude
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Calculate regression line values
regress_values = x_values * slope + intercept

# Create scatter plot
plt.scatter(x_values, y_values)

# Plot regression line
plt.plot(x_values, regress_values, "r")

# Annotate the equation of the line
line_eq = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
plt.annotate(line_eq, (-30, 40), fontsize=15, color="red")

# Set labels and title
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("Southern Hemisphere - Max Temperature vs. Latitude")

# Show plot
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** In the Southern Hemisphere, the linear regression equation y = 0.68x + 80.81 shows that as you move closer to the equator (lower latitudes), the temperature tends to increase. Conversely, in the Northern Hemisphere, the linear regression equation y = -0.67x + 90.94 indicates that as you move further away from the equator (higher latitudes), the temperature tends to decrease. These findings suggest that there is a general trend of temperature decreasing as you move away from the equator in either hemisphere.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere Humidity vs. Latitude Linear Regression Plot
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Calculate regression line values
regress_values = x_values * slope + intercept

# Create scatter plot
plt.scatter(x_values, y_values)

# Plot regression line
plt.plot(x_values, regress_values, "r")

# Annotate the equation of the line
line_eq = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
plt.annotate(line_eq, (45, 10), fontsize=15, color="red")

# Set labels and title
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Northern Hemisphere - Humidity vs. Latitude")

# Show plot
plt.show()

# %%
# Southern Hemisphere Humidity vs. Latitude Linear Regression Plot
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Calculate regression line values
regress_values = x_values * slope + intercept

# Create scatter plot
plt.scatter(x_values, y_values)

# Plot regression line
plt.plot(x_values, regress_values, "r")

# Annotate the equation of the line
line_eq = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
plt.annotate(line_eq, (-50, 20), fontsize=15, color="red")

# Set labels and title
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Southern Hemisphere - Humidity vs. Latitude")

# Show plot
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** In the Southern Hemisphere, there is a slight positive correlation between humidity and latitude, as indicated by the linear regression equation y = 0.19x + 81.18. This means that as you move away from the equator (higher latitudes), humidity tends to increase slightly. On the other hand, in the Northern Hemisphere, there is a weak negative correlation between humidity and latitude, as shown by the equation y = -0.05x + 68.01. This suggests that as you move further away from the equator (higher latitudes), humidity tends to slightly decrease. These findings imply that there are differences in humidity patterns between the two hemispheres.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere Cloudiness vs. Latitude Linear Regression Plot
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Calculate regression line values
regress_values = x_values * slope + intercept

# Create scatter plot
plt.scatter(x_values, y_values)

# Plot regression line
plt.plot(x_values, regress_values, "r")

# Annotate the equation of the line
line_eq = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
plt.annotate(line_eq, (50, 30), fontsize=15, color="red")

# Set labels and title
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Northern Hemisphere - Cloudiness vs. Latitude")

# Show plot
plt.show()

# %%
# Southern Hemisphere Cloudiness vs. Latitude Linear Regression Plot
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Calculate regression line values
regress_values = x_values * slope + intercept

# Create scatter plot
plt.scatter(x_values, y_values)

# Plot regression line
plt.plot(x_values, regress_values, "r")

# Annotate the equation of the line
line_eq = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
plt.annotate(line_eq, (-50, 40), fontsize=15, color="red")

# Set labels and title
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Southern Hemisphere - Cloudiness vs. Latitude")

# Show plot
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** Both hemispheres exhibit a similar pattern in cloudiness with respect to latitude. In the Northern Hemisphere, the linear regression equation y = -0.04x + 53.51 indicates a slight negative correlation, suggesting that as you move away from the equator (higher latitudes), cloudiness tends to slightly decrease. Similarly, in the Southern Hemisphere, the linear regression equation y = -0.57x + 44.5 shows a moderate negative correlation, indicating that as you move closer to the equator (lower latitudes), cloudiness tends to decrease. These findings suggest a general trend of decreasing cloudiness as you move away from the equator in both hemispheres.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere Wind Speed vs. Latitude Linear Regression Plot
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Calculate regression line values
regress_values = x_values * slope + intercept

# Create scatter plot
plt.scatter(x_values, y_values)

# Plot regression line
plt.plot(x_values, regress_values, "r")

# Annotate the equation of the line
line_eq = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
plt.annotate(line_eq, (10, 25), fontsize=15, color="red")

# Set labels and title
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Northern Hemisphere - Wind Speed vs. Latitude")

# Show plot
plt.show()

# %%
# Southern Hemisphere Wind Speed vs. Latitude Linear Regression Plot
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Calculate regression line values
regress_values = x_values * slope + intercept

# Create scatter plot
plt.scatter(x_values, y_values)

# Plot regression line
plt.plot(x_values, regress_values, "r")

# Annotate the equation of the line
line_eq = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
plt.annotate(line_eq, (-50, 20), fontsize=15, color="red")

# Set labels and title
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Southern Hemisphere - Wind Speed vs. Latitude")

# Show plot
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** The relationship between wind speed and latitude varies in the two hemispheres. In the Northern Hemisphere, the linear regression equation y = 0.0x + 8.08 suggests that there is no significant correlation between wind speed and latitude. On the other hand, in the Southern Hemisphere, the linear regression equation y = -0.06x + 5.54 indicates a slight negative correlation. This means that as you move closer to the equator (lower latitudes), wind speed tends to decrease slightly. These findings highlight the potential differences in wind speed patterns between the two hemispheres.
